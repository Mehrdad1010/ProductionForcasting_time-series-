# %%
import warnings
warnings.filterwarnings('ignore')


import matplotlib.pylab as plt
import pandas as pd
from Data_Prepear import data_prepear
# %pylab inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 7
#       5 import matplotlib.pylab as plt
#       6 import pandas as pd
# ----> 7 from Data_Prepear import data_prepear
#       8 get_ipython().run_line_magic('pylab', 'inline')
#
# ModuleNotFoundError: No module named 'Data_Prepear'

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well2.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
df1 = df1[(df1["dp_tubing"] > 100) & (df1["bhp"] > 200) & (df1["bht"] > 80)]
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2013-07-24', periods=1152, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')

df = df[[
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"]]
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df.dropna(inplace=True)
df.head()
# Out:
#                    bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P  \
# date
# 2013-07-31  273.946931  105.551370  179.382345          2.540804
# 2013-08-03  277.797679  104.933215  181.302141          6.116182
# 2013-08-04  273.594368  105.439765  177.392876          9.951288
# 2013-08-05  272.298494  105.537800  176.786078          9.758748
# 2013-08-06  271.560953  105.584750  176.519376          9.882110
#
#                        QG  Time
# date
# 2013-07-31  137705.269214     7
# 2013-08-03  141268.448264    10
# 2013-08-04  161227.000000    11
# 2013-08-05  160270.490000    12
# 2013-08-06  160951.300000    13

# %%
create_data = data_prepear(df, target_col ="QG")
X, y = create_data.creator()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 create_data = data_prepear(df, target_col ="QG")
#       2 X, y = create_data.creator()
#
# NameError: name 'data_prepear' is not defined

# %%
from pyFTS.partitioners import Grid

fs = Grid.GridPartitioner(data=df,npart=12)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[15,5])

fs.plot(ax)

# %%
fuzzyfied = fs.fuzzyfy(df, method='maximum', mode='sets')

fuzzyfied
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 fuzzyfied = fs.fuzzyfy(df, method='maximum', mode='sets')
#       3 fuzzyfied
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/partitioners/partitioner.py:162, in Partitioner.fuzzyfy(self, data, **kwargs)
#     159 mode = kwargs.get('mode', 'sets')
#     160 method = kwargs.get('method', 'fuzzy')
# --> 162 nearest = self.search(data, type='index')
#     163 mv = np.zeros(self.partitions)
#     165 for ix in nearest:
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/partitioners/partitioner.py:250, in Partitioner.search(self, data, **kwargs)
#     247 type = kwargs.get('type','index')
#     248 results = kwargs.get('results', 3)
# --> 250 _, ix = self.kdtree.query([data, data, data], results)
#     252 if type == 'name':
#     253     return [self.ordered_sets[k] for k in sorted(ix)]
#
# File /usr/local/lib/python3.11/dist-packages/scipy/spatial/_kdtree.py:475, in KDTree.query(self, x, k, eps, p, distance_upper_bound, workers)
#     472 if k is None:
#     473     raise ValueError("k must be an integer or a sequence of integers")
# --> 475 d, i = super().query(x, k, eps, p, distance_upper_bound, workers)
#     476 if isinstance(i, int):
#     477     i = np.intp(i)
#
# File _ckdtree.pyx:791, in scipy.spatial._ckdtree.cKDTree.query()
#
# File _ckdtree.pyx:1623, in scipy.spatial._ckdtree.num_points()
#
# ValueError: x must consist of vectors of length 3 but has shape (3, 1114, 6)

# %%
from pyFTS.common import FLR

patterns = FLR.generate_non_recurrent_flrs(fuzzyfied)

print([str(k) for k in patterns])
# Out:
# ['A0 -> A0', 'A0 -> A1', 'A1 -> A1']

# %%
from pyFTS.models import chen

model = chen.ConventionalFTS(partitioner=fs)
model.fit(df)
print(model)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from pyFTS.models import chen
#       3 model = chen.ConventionalFTS(partitioner=fs)
#       4 model.fit(df)
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/models/chen.py:8
#       1 """
#       2 First Order Conventional Fuzzy Time Series by Chen (1996)
#       3
#       4 S.-M. Chen, “Forecasting enrollments based on fuzzy time series,” Fuzzy Sets Syst., vol. 81, no. 3, pp. 311–319, 1996.
#       5 """
#       7 import numpy as np
# ----> 8 from pyFTS.common import FuzzySet, FLR, fts, flrg
#      11 class ConventionalFLRG(flrg.FLRG):
#      12     """First Order Conventional Fuzzy Logical Relationship Group"""
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/common/fts.py:3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from pyFTS.common import FuzzySet, Util
#       4 from pyFTS.common.transformations import transformation
#       5 from pyFTS.partitioners import partitioner
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/common/Util.py:11
#       9 import matplotlib.cm as cmx
#      10 import matplotlib.colors as pltcolors
# ---> 11 from pyFTS.probabilistic import ProbabilityDistribution
#      12 from pyFTS.common import Transformations
#      15 def plot_compared_intervals_ahead(original, models, colors, distributions, time_from, time_to, intervals = True,
#      16                                save=False, file=None, tam=[20, 5], resolution=None,
#      17                                cmap='Blues', linewidth=1.5):
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/probabilistic/ProbabilityDistribution.py:4
#       2 import matplotlib.pyplot as plt
#       3 from pyFTS.common import SortedCollection
# ----> 4 from pyFTS.probabilistic import kde
#       7 def from_point(x,**kwargs):
#       8     """
#       9     Create a probability distribution from a scalar value
#      10
#    (...)
#      13     :return: the ProbabilityDistribution object
#      14     """
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/probabilistic/kde.py:7
#       1 # -*- coding: utf8 -*-
#       3 """
#       4 Kernel Density Estimation
#       5 """
# ----> 7 from pyFTS.common import Transformations
#       8 import numpy as np
#      11 class KernelSmoothing(object):
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/common/Transformations.py:14
#      12 from pyFTS.common.transformations.boxcox import BoxCox
#      13 from pyFTS.common.transformations.roi import ROI
# ---> 14 from pyFTS.common.transformations.trend import LinearTrend
#      15 from pyFTS.common.transformations.som import SOMTransformation
#      16 from pyFTS.common.transformations.autoencoder import AutoencoderTransformation
#
# File /usr/local/lib/python3.11/dist-packages/pyFTS/common/transformations/trend.py:2
#       1 from pyFTS.common.transformations.transformation import Transformation
# ----> 2 from pandas import datetime
#       3 from sklearn.linear_model import LinearRegression
#       4 import numpy as np
#
# ImportError: cannot import name 'datetime' from 'pandas' (/usr/local/lib/python3.11/dist-packages/pandas/__init__.py)
