# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")
from tensorflow import keras
from sklearn.cluster import KMeans
import random
import tensorflow as tf
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from Data_Prepear import data_prepear
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.models import Sequential
import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib.offsetbox import AnchoredText
import seaborn as sns
tf.__version__
from xgboost import XGBRegressor
# Out:
# 2024-10-26 00:58:56.572588: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 00:58:56.575537: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 00:58:56.584382: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 00:58:56.600231: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 00:58:56.604506: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 00:58:56.616154: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-26 00:58:57.539288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well1.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
# df1 = df1[(df1["dp_tubing"] > 100) & (df1["bhp"] > 200) & (df1["bht"] > 80)]
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2014-04-21', periods=717, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')

df = df[[
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"]]
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df.dropna(inplace=True)
df.head()
# Out:
#                    bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P         QG  \
# date
# 2014-04-21  301.375641  102.676379  204.795183         20.989748       0.00
# 2014-04-22  289.421362  106.353209  182.059312         43.343451   90439.09
# 2014-04-23  270.239793  107.643779  171.052782         47.167523  165720.39
# 2014-04-24  262.842747  107.869234  168.241977         47.732310  221707.31
# 2014-04-25  255.526995  107.971137  165.538903         48.533769  178063.52
#
#             Time
# date
# 2014-04-21     0
# 2014-04-22     1
# 2014-04-23     2
# 2014-04-24     3
# 2014-04-25     4

# %%
create_data = data_prepear(df, target_col ="QG", filter_value=65)
X_train, y_train, X_test, y_test = create_data.creator()

# %%
# Normalize features 
# Define the LSTM model
model = Sequential()
model.add(LSTM(input_shape = (32,1), units= 32, return_sequences = True))
model.add(LSTM(128, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(128,return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(1, activation="linear"))
# model.add(Activation("linear"))
model.compile(loss="mse", optimizer="adam")
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32, 32)         │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32, 128)        │        82,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 305,217 (1.16 MB)
#  Trainable params: 305,217 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(
    'best_model.keras',            # Path to save the model
    monitor='val_loss',          # Metric to monitor (you can change it)
    save_best_only=True,         # Only save the best model (based on the monitored metric)
    mode='min',                  # 'min' because we want to minimize validation loss
    verbose=1                    # Verbosity mode, to see saving details in console
)
t1 = datetime.datetime.now()
history = model.fit(x=X_train, y=y_train["y_step_1 QG"], epochs=1000, batch_size=30, validation_data = (X_test, y_test["y_step_1 QG"]), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=100), checkpoint], verbose=1, shuffle=False)
# EarlyStopping(monitor='val_loss', patience=200), 
t2 = datetime.datetime.now()
print("Compilation Time : ", t2-t1)
# Out:
# Epoch 1/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.0482
# Epoch 1: val_loss improved from inf to 0.64578, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - loss: 1.9159 - val_loss: 0.6458
# Epoch 2/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.0298
# Epoch 2: val_loss improved from 0.64578 to 0.63983, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.8973 - val_loss: 0.6398
# Epoch 3/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.0260
# Epoch 3: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.8934 - val_loss: 0.6433
# Epoch 4/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.0309
# Epoch 4: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.8976 - val_loss: 0.6464
# Epoch 5/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.0342
# Epoch 5: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.9003 - val_loss: 0.6493
# Epoch 6/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.0371
# Epoch 6: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.9029 - val_loss: 0.6500
# Epoch 7/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.0388
# Epoch 7: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.9043 - val_loss: 0.6505
# Epoch 8/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.0398
# Epoch 8: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9052 - val_loss: 0.6512
# Epoch 9/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.0406
# Epoch 9: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.9059 - val_loss: 0.6524
# Epoch 10/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.0420
# Epoch 10: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9071 - val_loss: 0.6531
# Epoch 11/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.0429
# Epoch 11: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.9079 - val_loss: 0.6539
# Epoch 12/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.0437
# Epoch 12: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.9086 - val_loss: 0.6551
# Epoch 13/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.0448
# Epoch 13: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.9093 - val_loss: 0.6686
# Epoch 14/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.0580
# Epoch 14: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.9215 - val_loss: 0.6556
# Epoch 15/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.0456
# Epoch 15: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.9102 - val_loss: 0.6562
# Epoch 16/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.0460
# Epoch 16: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9105 - val_loss: 0.6579
# Epoch 17/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.0471
# Epoch 17: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9115 - val_loss: 0.6596
# Epoch 18/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.0471
# Epoch 18: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.9114 - val_loss: 0.6741
# Epoch 19/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.0494
# Epoch 19: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9121 - val_loss: 0.9627
# Epoch 20/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.1187
# Epoch 20: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.9757 - val_loss: 0.7767
# Epoch 21/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.9698
# Epoch 21: val_loss did not improve from 0.63983
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.8247 - val_loss: 0.8474
# Epoch 22/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.9823
# Epoch 22: val_loss improved from 0.63983 to 0.59147, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.8542 - val_loss: 0.5915
# Epoch 23/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.2381
# Epoch 23: val_loss did not improve from 0.59147
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.0791 - val_loss: 0.7420
# Epoch 24/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.0111
# Epoch 24: val_loss improved from 0.59147 to 0.49568, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.8588 - val_loss: 0.4957
# Epoch 25/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.0864
# Epoch 25: val_loss improved from 0.49568 to 0.44390, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.9493 - val_loss: 0.4439
# Epoch 26/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.7626
# Epoch 26: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.6278 - val_loss: 0.5429
# Epoch 27/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.8585
# Epoch 27: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.7250 - val_loss: 0.6847
# Epoch 28/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.6540
# Epoch 28: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.5291 - val_loss: 1.3604
# Epoch 29/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.5214
# Epoch 29: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.4146 - val_loss: 1.1014
# Epoch 30/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.5742
# Epoch 30: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.4540 - val_loss: 1.3228
# Epoch 31/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4293
# Epoch 31: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3227 - val_loss: 0.8203
# Epoch 32/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.3121
# Epoch 32: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.2177 - val_loss: 1.1826
# Epoch 33/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.3353
# Epoch 33: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.2352 - val_loss: 0.9431
# Epoch 34/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2374
# Epoch 34: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.1464 - val_loss: 1.0226
# Epoch 35/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.3279
# Epoch 35: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.2276 - val_loss: 0.9806
# Epoch 36/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0700
# Epoch 36: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.9954 - val_loss: 0.4877
# Epoch 37/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.3169
# Epoch 37: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.2248 - val_loss: 1.5193
# Epoch 38/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.1670
# Epoch 38: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.0874 - val_loss: 1.1146
# Epoch 39/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.1521
# Epoch 39: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.0759 - val_loss: 0.9625
# Epoch 40/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2512
# Epoch 40: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.1605 - val_loss: 0.8618
# Epoch 41/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9997
# Epoch 41: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.9326 - val_loss: 0.8843
# Epoch 42/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.2192
# Epoch 42: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.1271 - val_loss: 0.7920
# Epoch 43/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0446
# Epoch 43: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9711 - val_loss: 0.5181
# Epoch 44/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.0450
# Epoch 44: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.9745 - val_loss: 1.2161
# Epoch 45/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0282
# Epoch 45: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9583 - val_loss: 1.1326
# Epoch 46/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9758
# Epoch 46: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9152 - val_loss: 1.2227
# Epoch 47/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2774
# Epoch 47: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.1815 - val_loss: 0.9672
# Epoch 48/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.9339
# Epoch 48: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.8742 - val_loss: 1.0090
# Epoch 49/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0285
# Epoch 49: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.9576 - val_loss: 1.0229
# Epoch 50/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9106
# Epoch 50: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.8512 - val_loss: 0.8522
# Epoch 51/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0986
# Epoch 51: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.0179 - val_loss: 0.8208
# Epoch 52/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.9002
# Epoch 52: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.8433 - val_loss: 1.0317
# Epoch 53/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8608
# Epoch 53: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.8044 - val_loss: 1.0913
# Epoch 54/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9007
# Epoch 54: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8383 - val_loss: 0.8943
# Epoch 55/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.7968
# Epoch 55: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.7428 - val_loss: 0.7414
# Epoch 56/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9130
# Epoch 56: val_loss did not improve from 0.44390
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.8501 - val_loss: 0.8018
# Epoch 57/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.7031
# Epoch 57: val_loss improved from 0.44390 to 0.29016, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6609 - val_loss: 0.2902
# Epoch 58/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8386
# Epoch 58: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.7916 - val_loss: 1.2179
# Epoch 59/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9632
# Epoch 59: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8992 - val_loss: 1.0325
# Epoch 60/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.9261
# Epoch 60: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.8763 - val_loss: 1.0269
# Epoch 61/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.2031
# Epoch 61: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.1117 - val_loss: 0.9883
# Epoch 62/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.8396
# Epoch 62: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.7828 - val_loss: 0.9307
# Epoch 63/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7888
# Epoch 63: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.7359 - val_loss: 0.9337
# Epoch 64/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.8027
# Epoch 64: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7491 - val_loss: 0.8579
# Epoch 65/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.7962
# Epoch 65: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7439 - val_loss: 0.9031
# Epoch 66/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.7531
# Epoch 66: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.7034 - val_loss: 0.9168
# Epoch 67/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.7164
# Epoch 67: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6725 - val_loss: 0.8539
# Epoch 68/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.7013
# Epoch 68: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6586 - val_loss: 0.8067
# Epoch 69/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.7725
# Epoch 69: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.7215 - val_loss: 0.8416
# Epoch 70/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6985
# Epoch 70: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6588 - val_loss: 0.8455
# Epoch 71/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.7730
# Epoch 71: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.7211 - val_loss: 0.8299
# Epoch 72/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.6645
# Epoch 72: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.6282 - val_loss: 0.8102
# Epoch 73/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6446
# Epoch 73: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.6087 - val_loss: 0.7408
# Epoch 74/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.8376
# Epoch 74: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.7794 - val_loss: 0.8975
# Epoch 75/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5923
# Epoch 75: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5611 - val_loss: 0.9877
# Epoch 76/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.6060
# Epoch 76: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.5720 - val_loss: 0.8982
# Epoch 77/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5660
# Epoch 77: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5336 - val_loss: 0.5787
# Epoch 78/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4231
# Epoch 78: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.4050 - val_loss: 1.0533
# Epoch 79/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4896
# Epoch 79: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4673 - val_loss: 1.0999
# Epoch 80/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4559
# Epoch 80: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4398 - val_loss: 0.9784
# Epoch 81/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.0198
# Epoch 81: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.9473 - val_loss: 0.8943
# Epoch 82/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4362
# Epoch 82: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.4176 - val_loss: 0.9844
# Epoch 83/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2967
# Epoch 83: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2887 - val_loss: 1.0423
# Epoch 84/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4026
# Epoch 84: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3835 - val_loss: 1.0016
# Epoch 85/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3139
# Epoch 85: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3019 - val_loss: 0.9646
# Epoch 86/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4555
# Epoch 86: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4287 - val_loss: 0.7560
# Epoch 87/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3741
# Epoch 87: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3559 - val_loss: 0.8377
# Epoch 88/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5012
# Epoch 88: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.4714 - val_loss: 0.7491
# Epoch 89/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3045
# Epoch 89: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2948 - val_loss: 0.9257
# Epoch 90/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5172
# Epoch 90: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.4870 - val_loss: 0.7553
# Epoch 91/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3035
# Epoch 91: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2948 - val_loss: 0.7939
# Epoch 92/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3710
# Epoch 92: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3548 - val_loss: 0.7153
# Epoch 93/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3083
# Epoch 93: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2953 - val_loss: 0.7522
# Epoch 94/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2724
# Epoch 94: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2624 - val_loss: 0.7577
# Epoch 95/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3018
# Epoch 95: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2872 - val_loss: 0.6963
# Epoch 96/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4633
# Epoch 96: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4354 - val_loss: 0.8230
# Epoch 97/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.7650
# Epoch 97: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.7092 - val_loss: 0.6836
# Epoch 98/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4287
# Epoch 98: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4038 - val_loss: 0.9035
# Epoch 99/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2655
# Epoch 99: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2563 - val_loss: 0.7261
# Epoch 100/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2753
# Epoch 100: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2650 - val_loss: 0.5585
# Epoch 101/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2571
# Epoch 101: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2474 - val_loss: 0.9155
# Epoch 102/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2542
# Epoch 102: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2463 - val_loss: 0.7944
# Epoch 103/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2643
# Epoch 103: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2555 - val_loss: 0.7116
# Epoch 104/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3010
# Epoch 104: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2864 - val_loss: 0.7511
# Epoch 105/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2866
# Epoch 105: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2753 - val_loss: 0.7324
# Epoch 106/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4279
# Epoch 106: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4025 - val_loss: 0.6859
# Epoch 107/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2822
# Epoch 107: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2702 - val_loss: 0.5522
# Epoch 108/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3118
# Epoch 108: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2984 - val_loss: 0.8117
# Epoch 109/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2062
# Epoch 109: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2009 - val_loss: 0.6723
# Epoch 110/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2205
# Epoch 110: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2124 - val_loss: 0.6349
# Epoch 111/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2604
# Epoch 111: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2484 - val_loss: 0.6438
# Epoch 112/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2522
# Epoch 112: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2417 - val_loss: 0.6100
# Epoch 113/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2452
# Epoch 113: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2353 - val_loss: 0.7351
# Epoch 114/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2136
# Epoch 114: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2066 - val_loss: 0.6166
# Epoch 115/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2532
# Epoch 115: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2440 - val_loss: 0.7344
# Epoch 116/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2203
# Epoch 116: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2139 - val_loss: 0.6039
# Epoch 117/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2011
# Epoch 117: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1954 - val_loss: 0.5803
# Epoch 118/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2144
# Epoch 118: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2072 - val_loss: 0.7550
# Epoch 119/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2049
# Epoch 119: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1979 - val_loss: 0.7769
# Epoch 120/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2142
# Epoch 120: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2075 - val_loss: 0.7780
# Epoch 121/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2996
# Epoch 121: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2849 - val_loss: 0.6193
# Epoch 122/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3086
# Epoch 122: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.2950 - val_loss: 0.6082
# Epoch 123/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.5376
# Epoch 123: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.5027 - val_loss: 0.6617
# Epoch 124/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2444
# Epoch 124: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.2367 - val_loss: 0.6676
# Epoch 125/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2230
# Epoch 125: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2168 - val_loss: 0.7481
# Epoch 126/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2375
# Epoch 126: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.2289 - val_loss: 0.6511
# Epoch 127/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2334
# Epoch 127: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2269 - val_loss: 0.7718
# Epoch 128/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2564
# Epoch 128: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2451 - val_loss: 0.6137
# Epoch 129/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2242
# Epoch 129: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2175 - val_loss: 0.7614
# Epoch 130/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3815
# Epoch 130: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3594 - val_loss: 0.7598
# Epoch 131/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2452
# Epoch 131: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2355 - val_loss: 0.7537
# Epoch 132/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2831
# Epoch 132: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.2691 - val_loss: 0.6523
# Epoch 133/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2333
# Epoch 133: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2227 - val_loss: 0.6758
# Epoch 134/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2379
# Epoch 134: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.2271 - val_loss: 0.6836
# Epoch 135/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1911
# Epoch 135: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1849 - val_loss: 0.6142
# Epoch 136/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2077
# Epoch 136: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1996 - val_loss: 0.7101
# Epoch 137/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1874
# Epoch 137: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1821 - val_loss: 0.6349
# Epoch 138/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1800
# Epoch 138: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1747 - val_loss: 0.6829
# Epoch 139/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2004
# Epoch 139: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1936 - val_loss: 0.6586
# Epoch 140/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2120
# Epoch 140: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2039 - val_loss: 0.6129
# Epoch 141/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2536
# Epoch 141: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2405 - val_loss: 0.6645
# Epoch 142/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1912
# Epoch 142: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1847 - val_loss: 0.5696
# Epoch 143/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2296
# Epoch 143: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2190 - val_loss: 0.7242
# Epoch 144/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2557
# Epoch 144: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2442 - val_loss: 0.5968
# Epoch 145/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2516
# Epoch 145: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2388 - val_loss: 0.5537
# Epoch 146/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1815
# Epoch 146: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1766 - val_loss: 0.8533
# Epoch 147/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2165
# Epoch 147: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2097 - val_loss: 0.8351
# Epoch 148/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2452
# Epoch 148: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2364 - val_loss: 0.6680
# Epoch 149/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4031
# Epoch 149: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3787 - val_loss: 0.6741
# Epoch 150/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2010
# Epoch 150: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1944 - val_loss: 0.4927
# Epoch 151/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2683
# Epoch 151: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2590 - val_loss: 0.9473
# Epoch 152/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2410
# Epoch 152: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2358 - val_loss: 0.8207
# Epoch 153/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2776
# Epoch 153: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2688 - val_loss: 0.8578
# Epoch 154/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4070
# Epoch 154: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3854 - val_loss: 0.6616
# Epoch 155/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4018
# Epoch 155: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3782 - val_loss: 0.6655
# Epoch 156/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.6175
# Epoch 156: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.5742 - val_loss: 0.6814
# Epoch 157/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2579
# Epoch 157: val_loss did not improve from 0.29016
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2490 - val_loss: 0.8016
# Compilation Time :  0:01:30.145986

# %%
plt.figure(figsize=(20,6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show()

# %%
y_fit = pd.DataFrame(model.predict(X_train), index=X_train.index)
y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
ss = StandardScaler()
ss.fit(df.QG.values.reshape(df.QG.shape[0],1))
true_y_train = ss.inverse_transform(y_train["y_step_1 QG"].values.reshape(y_train["y_step_1 QG"].shape[0],1))
true_y_test = ss.inverse_transform(y_test["y_step_1 QG"].values.reshape(y_test["y_step_1 QG"].shape[0],1))
true_y_fit = ss.inverse_transform(y_fit)
true_y_pred = ss.inverse_transform(y_pred)

# %%
train_rmse = mean_squared_error(true_y_train, true_y_fit, squared=False)
test_rmse = mean_squared_error(true_y_test , true_y_pred, squared=False)
range_train =  np.max(true_y_train) - np.min(true_y_train)
range_test = np.max(true_y_test) - np.min(true_y_test)
print("train RMSE: ",train_rmse)
print("train Range:",range_train)
print("Percent_Erorr:", (train_rmse/range_train)*100, "%")
print("test_RMSE: ", test_rmse)
print("test Range:",range_test)
print("Percent_Erorr:", (test_rmse/range_test)*100, "%")
# Out:
# train RMSE:  13483.923717315456
# train Range: 221707.31
# Percent_Erorr: 6.0818579763181715 %
# test_RMSE:  30540.192573274395
# test Range: 82782.98000000001
# Percent_Erorr: 36.89187387706313 %
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
plt.plot(true_y_train)
plt.plot(true_y_fit)

# %%
plt.plot(true_y_test)
plt.plot(true_y_pred)

# %%
corr = r2_score(true_y_train, true_y_fit)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_train,
    y = true_y_fit,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="Train", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'Train'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]

# %%
corr = r2_score(true_y_test, true_y_pred)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_test,
    y = true_y_pred,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="test", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'test'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]
