# %%
# import laybrarys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from pathlib import Path
from warnings import simplefilter
from scipy.signal import periodogram
from sklearn.model_selection import train_test_split
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from plot_fig import *
from statsmodels.graphics.tsaplots import plot_pacf
simplefilter("ignore")

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well1.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2014-04-21', periods=717, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')
df.head()
# Out:
#         date   well_name         bhp         bht   dp_tubing  \
# 0 2014-04-21  15/9-F-1 C  301.375641  102.676379  204.795183
# 1 2014-04-22  15/9-F-1 C  289.421362  106.353209  182.059312
# 2 2014-04-23  15/9-F-1 C  270.239793  107.643779  171.052782
# 3 2014-04-24  15/9-F-1 C  262.842747  107.869234  168.241977
# 4 2014-04-25  15/9-F-1 C  255.526995  107.971137  165.538903
#
#    AVG_CHOKE_SIZE_P         thp        tht  choke_size_percentage       QL  \
# 0         20.989748   96.580458  19.196819              69.775570     0.00
# 1         43.343451  107.362050  37.939251              78.935409   631.47
# 2         47.167523   99.187011  60.756579              70.627109  1166.46
# 3         47.732310   94.600770  63.046800              66.049151  1549.81
# 4         48.533769   89.988092  64.547229              61.405386  1248.70
#
#           QG    well6_inj    well7_inj
# 0       0.00  5662.274117  4768.821610
# 1   90439.09  5789.492554  4247.453942
# 2  165720.39  6465.918884  5060.795754
# 3  221707.31  6158.800000  5236.800000
# 4  178063.52  6412.503662  5423.603912

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   717 non-null    datetime64[ns]
#  1   well_name              438 non-null    object
#  2   bhp                    438 non-null    float64
#  3   bht                    438 non-null    float64
#  4   dp_tubing              438 non-null    float64
#  5   AVG_CHOKE_SIZE_P       438 non-null    float64
#  6   thp                    438 non-null    float64
#  7   tht                    438 non-null    float64
#  8   choke_size_percentage  438 non-null    float64
#  9   QL                     438 non-null    float64
#  10  QG                     438 non-null    float64
#  11  well6_inj              438 non-null    float64
#  12  well7_inj              438 non-null    float64
# dtypes: datetime64[ns](1), float64(11), object(1)
# memory usage: 72.9+ KB

# %%
df.isna().sum()
# Out:
# bhp                 0
# bht                 0
# dp_tubing           0
# AVG_CHOKE_SIZE_P    0
# QG                  0
# Time                0
# dtype: int64

# %%
df = df.loc[:, [
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"
]]

df.head()
# Out:
#         date         bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P         QG
# 0 2014-04-21  301.375641  102.676379  204.795183         20.989748       0.00
# 1 2014-04-22  289.421362  106.353209  182.059312         43.343451   90439.09
# 2 2014-04-23  270.239793  107.643779  171.052782         47.167523  165720.39
# 3 2014-04-24  262.842747  107.869234  168.241977         47.732310  221707.31
# 4 2014-04-25  255.526995  107.971137  165.538903         48.533769  178063.52

# %%
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df = df.dropna()

# %%
# Define a list of column names and their titles
plot_columns = [
    ('QG', 'Gas Production Rate'),
    ('AVG_CHOKE_SIZE_P', 'Change of the choke size'),
    ('dp_tubing', 'Change of the tubing size'),
    ('bht', 'Change of the bottom hole temp'),
    ('bhp', 'Change of the bottom hole pressure')
]

# Loop through each column and plot
for column, title in plot_columns:
    fig, ax = plt.subplots()
    ax.plot('Time', column, data=df, color='0.75')
    ax = sns.regplot(x='Time', y=column, data=df, ci=None, scatter_kws=dict(color='0.25'))
    ax.set_title(title)
    plt.show()

# %%
moving_average = df["QG"].rolling(
    window=120,       # 365-day window
    center=True,      # puts the average at the center of the window
    min_periods=30,  # choose about half the window size
).mean()              # compute the mean (could also do median, std, min, max, ...)

ax = df["QG"].plot(style=".", color="0.5")
moving_average.plot(
    ax=ax, linewidth=3, title="Tunnel Traffic - 365-Day Moving Average", legend=False,
);

# %%
# add the lag
df["Lag_1"] = df["QG"].shift(1)
df.dropna(inplace=True)

# %%
X = df.copy()
y = X.pop("QG")

# Label encoding for categoricals
for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# All discrete features should now have integer dtypes (double-check this before using MI!)
discrete_features = X.dtypes == int

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y):
    mi_scores = mutual_info_regression(X, y)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y)
# mi_scores[::3]  # show a few features with their MI scores
mi_scores
# Out:
# Lag_1               1.420837
# Time                1.308741
# dp_tubing           1.013078
# AVG_CHOKE_SIZE_P    0.948226
# bht                 0.683104
# bhp                 0.618090
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_66e7e_row0_col0, #T_66e7e_row1_col1, #T_66e7e_row2_col2, #T_66e7e_row3_col3, #T_66e7e_row4_col4, #T_66e7e_row5_col5, #T_66e7e_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_66e7e_row0_col1, #T_66e7e_row0_col3, #T_66e7e_row1_col0, #T_66e7e_row2_col4, #T_66e7e_row2_col6, #T_66e7e_row4_col5, #T_66e7e_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_66e7e_row0_col2 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_66e7e_row0_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_66e7e_row0_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_66e7e_row0_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_66e7e_row1_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_66e7e_row1_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_66e7e_row1_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_66e7e_row1_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_66e7e_row1_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_66e7e_row2_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_66e7e_row2_col1, #T_66e7e_row5_col6 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_66e7e_row2_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_66e7e_row2_col5 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_66e7e_row3_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_66e7e_row3_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_66e7e_row3_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_66e7e_row3_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_66e7e_row3_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_66e7e_row3_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_66e7e_row4_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_66e7e_row4_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_66e7e_row4_col2, #T_66e7e_row6_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_66e7e_row4_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_66e7e_row4_col6, #T_66e7e_row6_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_66e7e_row5_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_66e7e_row5_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_66e7e_row5_col2 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_66e7e_row5_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_66e7e_row5_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_66e7e_row6_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_66e7e_row6_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_66e7e_row6_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_66e7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66e7e_level0_col0" class="col_heading level0 col0" >bhp</th>
#       <th id="T_66e7e_level0_col1" class="col_heading level0 col1" >bht</th>
#       <th id="T_66e7e_level0_col2" class="col_heading level0 col2" >dp_tubing</th>
#       <th id="T_66e7e_level0_col3" class="col_heading level0 col3" >AVG_CHOKE_SIZE_P</th>
#       <th id="T_66e7e_level0_col4" class="col_heading level0 col4" >QG</th>
#       <th id="T_66e7e_level0_col5" class="col_heading level0 col5" >Time</th>
#       <th id="T_66e7e_level0_col6" class="col_heading level0 col6" >Lag_1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66e7e_level0_row0" class="row_heading level0 row0" >bhp</th>
#       <td id="T_66e7e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_66e7e_row0_col1" class="data row0 col1" >-0.474699</td>
#       <td id="T_66e7e_row0_col2" class="data row0 col2" >0.734845</td>
#       <td id="T_66e7e_row0_col3" class="data row0 col3" >-0.136762</td>
#       <td id="T_66e7e_row0_col4" class="data row0 col4" >-0.272531</td>
#       <td id="T_66e7e_row0_col5" class="data row0 col5" >0.389244</td>
#       <td id="T_66e7e_row0_col6" class="data row0 col6" >-0.343471</td>
#     </tr>
#     <tr>
#       <th id="T_66e7e_level0_row1" class="row_heading level0 row1" >bht</th>
#       <td id="T_66e7e_row1_col0" class="data row1 col0" >-0.474699</td>
#       <td id="T_66e7e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_66e7e_row1_col2" class="data row1 col2" >-0.323626</td>
#       <td id="T_66e7e_row1_col3" class="data row1 col3" >0.517716</td>
#       <td id="T_66e7e_row1_col4" class="data row1 col4" >0.195842</td>
#       <td id="T_66e7e_row1_col5" class="data row1 col5" >-0.049814</td>
#       <td id="T_66e7e_row1_col6" class="data row1 col6" >0.155016</td>
#     </tr>
#     <tr>
#       <th id="T_66e7e_level0_row2" class="row_heading level0 row2" >dp_tubing</th>
#       <td id="T_66e7e_row2_col0" class="data row2 col0" >0.734845</td>
#       <td id="T_66e7e_row2_col1" class="data row2 col1" >-0.323626</td>
#       <td id="T_66e7e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_66e7e_row2_col3" class="data row2 col3" >0.037094</td>
#       <td id="T_66e7e_row2_col4" class="data row2 col4" >-0.717542</td>
#       <td id="T_66e7e_row2_col5" class="data row2 col5" >0.770468</td>
#       <td id="T_66e7e_row2_col6" class="data row2 col6" >-0.728212</td>
#     </tr>
#     <tr>
#       <th id="T_66e7e_level0_row3" class="row_heading level0 row3" >AVG_CHOKE_SIZE_P</th>
#       <td id="T_66e7e_row3_col0" class="data row3 col0" >-0.136762</td>
#       <td id="T_66e7e_row3_col1" class="data row3 col1" >0.517716</td>
#       <td id="T_66e7e_row3_col2" class="data row3 col2" >0.037094</td>
#       <td id="T_66e7e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_66e7e_row3_col4" class="data row3 col4" >0.129698</td>
#       <td id="T_66e7e_row3_col5" class="data row3 col5" >0.225846</td>
#       <td id="T_66e7e_row3_col6" class="data row3 col6" >-0.064812</td>
#     </tr>
#     <tr>
#       <th id="T_66e7e_level0_row4" class="row_heading level0 row4" >QG</th>
#       <td id="T_66e7e_row4_col0" class="data row4 col0" >-0.272531</td>
#       <td id="T_66e7e_row4_col1" class="data row4 col1" >0.195842</td>
#       <td id="T_66e7e_row4_col2" class="data row4 col2" >-0.717542</td>
#       <td id="T_66e7e_row4_col3" class="data row4 col3" >0.129698</td>
#       <td id="T_66e7e_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_66e7e_row4_col5" class="data row4 col5" >-0.556005</td>
#       <td id="T_66e7e_row4_col6" class="data row4 col6" >0.884753</td>
#     </tr>
#     <tr>
#       <th id="T_66e7e_level0_row5" class="row_heading level0 row5" >Time</th>
#       <td id="T_66e7e_row5_col0" class="data row5 col0" >0.389244</td>
#       <td id="T_66e7e_row5_col1" class="data row5 col1" >-0.049814</td>
#       <td id="T_66e7e_row5_col2" class="data row5 col2" >0.770468</td>
#       <td id="T_66e7e_row5_col3" class="data row5 col3" >0.225846</td>
#       <td id="T_66e7e_row5_col4" class="data row5 col4" >-0.556005</td>
#       <td id="T_66e7e_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_66e7e_row5_col6" class="data row5 col6" >-0.547981</td>
#     </tr>
#     <tr>
#       <th id="T_66e7e_level0_row6" class="row_heading level0 row6" >Lag_1</th>
#       <td id="T_66e7e_row6_col0" class="data row6 col0" >-0.343471</td>
#       <td id="T_66e7e_row6_col1" class="data row6 col1" >0.155016</td>
#       <td id="T_66e7e_row6_col2" class="data row6 col2" >-0.728212</td>
#       <td id="T_66e7e_row6_col3" class="data row6 col3" >-0.064812</td>
#       <td id="T_66e7e_row6_col4" class="data row6 col4" >0.884753</td>
#       <td id="T_66e7e_row6_col5" class="data row6 col5" >-0.547981</td>
#       <td id="T_66e7e_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
_ = plot_lags(df["QG"], lags=30, nrows=6)
_ = plot_pacf(df["QG"], lags=30)
