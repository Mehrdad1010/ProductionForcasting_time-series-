# %%
# import laybrarys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from pathlib import Path
from warnings import simplefilter
from scipy.signal import periodogram
from sklearn.model_selection import train_test_split
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from plot_fig import *
from statsmodels.graphics.tsaplots import plot_pacf
simplefilter("ignore")

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well5.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2014-04-21', periods=717, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')
df.head()
# Out:
#         date    well_name         bhp         bht   dp_tubing  \
# 0 2014-04-21  15/9-F-15 D  199.786581  106.658980  155.118109
# 1 2014-04-22  15/9-F-15 D  199.969739  106.652065  155.260995
# 2 2014-04-23  15/9-F-15 D  199.773930  106.656580  155.136833
# 3 2014-04-24  15/9-F-15 D  204.997626  106.290154  158.704731
# 4 2014-04-25  15/9-F-15 D  199.749247  106.622406  154.847998
#
#    AVG_CHOKE_SIZE_P        thp        tht  choke_size_percentage          QL  \
# 0         12.403833  44.668472  34.595614              15.978979  248.550000
# 1         12.310589  44.708743  32.657590              16.389120  237.410000
# 2         11.740151  44.637097  26.916889              16.291807  232.749277
# 3         10.226906  46.292896  24.877963              17.664526  234.543845
# 4         12.133490  44.901249  28.526759              16.262747  247.230000
#
#              QG    well6_inj    well7_inj
# 0  38570.590000  5662.274117  4768.821610
# 1  34001.500000  5789.492554  4247.453942
# 2  33067.045161  6465.918884  5060.795754
# 3  33552.408709  6158.800000  5236.800000
# 4  35254.330000  6412.503662  5423.603912

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   717 non-null    datetime64[ns]
#  1   well_name              591 non-null    object
#  2   bhp                    591 non-null    float64
#  3   bht                    591 non-null    float64
#  4   dp_tubing              591 non-null    float64
#  5   AVG_CHOKE_SIZE_P       591 non-null    float64
#  6   thp                    591 non-null    float64
#  7   tht                    591 non-null    float64
#  8   choke_size_percentage  591 non-null    float64
#  9   QL                     591 non-null    float64
#  10  QG                     591 non-null    float64
#  11  well6_inj              591 non-null    float64
#  12  well7_inj              591 non-null    float64
# dtypes: datetime64[ns](1), float64(11), object(1)
# memory usage: 72.9+ KB

# %%
df.isna().sum()
# Out:
# date                       0
# well_name                126
# bhp                      126
# bht                      126
# dp_tubing                126
# AVG_CHOKE_SIZE_P         126
# thp                      126
# tht                      126
# choke_size_percentage    126
# QL                       126
# QG                       126
# well6_inj                126
# well7_inj                126
# dtype: int64

# %%
df = df.loc[:, [
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"
]]

df.head()
# Out:
#         date         bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P  \
# 0 2014-04-21  199.786581  106.658980  155.118109         12.403833
# 1 2014-04-22  199.969739  106.652065  155.260995         12.310589
# 2 2014-04-23  199.773930  106.656580  155.136833         11.740151
# 3 2014-04-24  204.997626  106.290154  158.704731         10.226906
# 4 2014-04-25  199.749247  106.622406  154.847998         12.133490
#
#              QG
# 0  38570.590000
# 1  34001.500000
# 2  33067.045161
# 3  33552.408709
# 4  35254.330000

# %%
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df = df.dropna()

# %%
# Define a list of column names and their titles
plot_columns = [
    ('QG', 'Gas Production Rate'),
    ('AVG_CHOKE_SIZE_P', 'Change of the choke size'),
    ('dp_tubing', 'Change of the tubing size'),
    ('bht', 'Change of the bottom hole temp'),
    ('bhp', 'Change of the bottom hole pressure')
]

# Loop through each column and plot
for column, title in plot_columns:
    fig, ax = plt.subplots()
    ax.plot('Time', column, data=df, color='0.75')
    ax = sns.regplot(x='Time', y=column, data=df, ci=None, scatter_kws=dict(color='0.25'))
    ax.set_title(title)
    plt.show()

# %%
moving_average = df["QG"].rolling(
    window=120,       # 365-day window
    center=True,      # puts the average at the center of the window
    min_periods=30,  # choose about half the window size
).mean()              # compute the mean (could also do median, std, min, max, ...)

ax = df["QG"].plot(style=".", color="0.5")
ax.set_ylabel("QG")
moving_average.plot(
    ax=ax, linewidth=3, title="120-Day Moving Average", legend=False,
);

# %%
# add the lag
df["Lag_1"] = df["QG"].shift(1)
df.dropna(inplace=True)

# %%
X = df.copy()
y = X.pop("QG")

# Label encoding for categoricals
for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# All discrete features should now have integer dtypes (double-check this before using MI!)
discrete_features = X.dtypes == int

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y):
    mi_scores = mutual_info_regression(X, y)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y)
# mi_scores[::3]  # show a few features with their MI scores
mi_scores
# Out:
# Time                1.793790
# Lag_1               1.783097
# dp_tubing           1.110012
# AVG_CHOKE_SIZE_P    1.022847
# bht                 0.830835
# bhp                 0.498872
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_43bcb_row0_col0, #T_43bcb_row1_col1, #T_43bcb_row2_col2, #T_43bcb_row3_col3, #T_43bcb_row4_col4, #T_43bcb_row5_col5, #T_43bcb_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_43bcb_row0_col1, #T_43bcb_row0_col3, #T_43bcb_row1_col0, #T_43bcb_row1_col2, #T_43bcb_row1_col5, #T_43bcb_row5_col4, #T_43bcb_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_43bcb_row0_col2 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_43bcb_row0_col4, #T_43bcb_row1_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_43bcb_row0_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_43bcb_row0_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_43bcb_row1_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_43bcb_row1_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_43bcb_row2_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_43bcb_row2_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_43bcb_row2_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_43bcb_row2_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_43bcb_row2_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_43bcb_row2_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_43bcb_row3_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_43bcb_row3_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_43bcb_row3_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_43bcb_row3_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_43bcb_row3_col5, #T_43bcb_row6_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_43bcb_row3_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_43bcb_row4_col0, #T_43bcb_row4_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_43bcb_row4_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_43bcb_row4_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_43bcb_row4_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_43bcb_row4_col6, #T_43bcb_row6_col4 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_43bcb_row5_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_43bcb_row5_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_43bcb_row5_col2 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_43bcb_row5_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_43bcb_row6_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_43bcb_row6_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_43bcb_row6_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_43bcb_row6_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_43bcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43bcb_level0_col0" class="col_heading level0 col0" >bhp</th>
#       <th id="T_43bcb_level0_col1" class="col_heading level0 col1" >bht</th>
#       <th id="T_43bcb_level0_col2" class="col_heading level0 col2" >dp_tubing</th>
#       <th id="T_43bcb_level0_col3" class="col_heading level0 col3" >AVG_CHOKE_SIZE_P</th>
#       <th id="T_43bcb_level0_col4" class="col_heading level0 col4" >QG</th>
#       <th id="T_43bcb_level0_col5" class="col_heading level0 col5" >Time</th>
#       <th id="T_43bcb_level0_col6" class="col_heading level0 col6" >Lag_1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43bcb_level0_row0" class="row_heading level0 row0" >bhp</th>
#       <td id="T_43bcb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_43bcb_row0_col1" class="data row0 col1" >-0.543479</td>
#       <td id="T_43bcb_row0_col2" class="data row0 col2" >0.745172</td>
#       <td id="T_43bcb_row0_col3" class="data row0 col3" >-0.098382</td>
#       <td id="T_43bcb_row0_col4" class="data row0 col4" >0.283028</td>
#       <td id="T_43bcb_row0_col5" class="data row0 col5" >0.468636</td>
#       <td id="T_43bcb_row0_col6" class="data row0 col6" >0.315965</td>
#     </tr>
#     <tr>
#       <th id="T_43bcb_level0_row1" class="row_heading level0 row1" >bht</th>
#       <td id="T_43bcb_row1_col0" class="data row1 col0" >-0.543479</td>
#       <td id="T_43bcb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_43bcb_row1_col2" class="data row1 col2" >-0.356232</td>
#       <td id="T_43bcb_row1_col3" class="data row1 col3" >0.363243</td>
#       <td id="T_43bcb_row1_col4" class="data row1 col4" >0.286447</td>
#       <td id="T_43bcb_row1_col5" class="data row1 col5" >-0.257879</td>
#       <td id="T_43bcb_row1_col6" class="data row1 col6" >0.134611</td>
#     </tr>
#     <tr>
#       <th id="T_43bcb_level0_row2" class="row_heading level0 row2" >dp_tubing</th>
#       <td id="T_43bcb_row2_col0" class="data row2 col0" >0.745172</td>
#       <td id="T_43bcb_row2_col1" class="data row2 col1" >-0.356232</td>
#       <td id="T_43bcb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_43bcb_row2_col3" class="data row2 col3" >0.246066</td>
#       <td id="T_43bcb_row2_col4" class="data row2 col4" >0.038169</td>
#       <td id="T_43bcb_row2_col5" class="data row2 col5" >0.894277</td>
#       <td id="T_43bcb_row2_col6" class="data row2 col6" >0.059061</td>
#     </tr>
#     <tr>
#       <th id="T_43bcb_level0_row3" class="row_heading level0 row3" >AVG_CHOKE_SIZE_P</th>
#       <td id="T_43bcb_row3_col0" class="data row3 col0" >-0.098382</td>
#       <td id="T_43bcb_row3_col1" class="data row3 col1" >0.363243</td>
#       <td id="T_43bcb_row3_col2" class="data row3 col2" >0.246066</td>
#       <td id="T_43bcb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_43bcb_row3_col4" class="data row3 col4" >0.154044</td>
#       <td id="T_43bcb_row3_col5" class="data row3 col5" >0.296158</td>
#       <td id="T_43bcb_row3_col6" class="data row3 col6" >0.173990</td>
#     </tr>
#     <tr>
#       <th id="T_43bcb_level0_row4" class="row_heading level0 row4" >QG</th>
#       <td id="T_43bcb_row4_col0" class="data row4 col0" >0.283028</td>
#       <td id="T_43bcb_row4_col1" class="data row4 col1" >0.286447</td>
#       <td id="T_43bcb_row4_col2" class="data row4 col2" >0.038169</td>
#       <td id="T_43bcb_row4_col3" class="data row4 col3" >0.154044</td>
#       <td id="T_43bcb_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_43bcb_row4_col5" class="data row4 col5" >-0.141636</td>
#       <td id="T_43bcb_row4_col6" class="data row4 col6" >0.660956</td>
#     </tr>
#     <tr>
#       <th id="T_43bcb_level0_row5" class="row_heading level0 row5" >Time</th>
#       <td id="T_43bcb_row5_col0" class="data row5 col0" >0.468636</td>
#       <td id="T_43bcb_row5_col1" class="data row5 col1" >-0.257879</td>
#       <td id="T_43bcb_row5_col2" class="data row5 col2" >0.894277</td>
#       <td id="T_43bcb_row5_col3" class="data row5 col3" >0.296158</td>
#       <td id="T_43bcb_row5_col4" class="data row5 col4" >-0.141636</td>
#       <td id="T_43bcb_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_43bcb_row5_col6" class="data row5 col6" >-0.135991</td>
#     </tr>
#     <tr>
#       <th id="T_43bcb_level0_row6" class="row_heading level0 row6" >Lag_1</th>
#       <td id="T_43bcb_row6_col0" class="data row6 col0" >0.315965</td>
#       <td id="T_43bcb_row6_col1" class="data row6 col1" >0.134611</td>
#       <td id="T_43bcb_row6_col2" class="data row6 col2" >0.059061</td>
#       <td id="T_43bcb_row6_col3" class="data row6 col3" >0.173990</td>
#       <td id="T_43bcb_row6_col4" class="data row6 col4" >0.660956</td>
#       <td id="T_43bcb_row6_col5" class="data row6 col5" >-0.135991</td>
#       <td id="T_43bcb_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
_ = plot_lags(df["QG"], lags=30, nrows=6)
_ = plot_pacf(df["QG"], lags=30)
