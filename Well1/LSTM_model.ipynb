# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")
from tensorflow import keras
from sklearn.cluster import KMeans
import random
import tensorflow as tf
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from Data_Prepear import data_prepear
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.models import Sequential
import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib.offsetbox import AnchoredText
import seaborn as sns
tf.__version__
from xgboost import XGBRegressor
# Out:
# 2024-10-26 16:29:07.086199: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 16:29:07.089001: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 16:29:07.098023: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 16:29:07.112902: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 16:29:07.117192: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 16:29:07.127695: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-26 16:29:07.952235: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well1.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
# df1 = df1[(df1["dp_tubing"] > 100) & (df1["bhp"] > 200) & (df1["bht"] > 80)]
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2014-04-21', periods=717, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')

df = df[[
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"]]
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df.dropna(inplace=True)
df.head()
# Out:
#                    bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P         QG  \
# date
# 2014-04-21  301.375641  102.676379  204.795183         20.989748       0.00
# 2014-04-22  289.421362  106.353209  182.059312         43.343451   90439.09
# 2014-04-23  270.239793  107.643779  171.052782         47.167523  165720.39
# 2014-04-24  262.842747  107.869234  168.241977         47.732310  221707.31
# 2014-04-25  255.526995  107.971137  165.538903         48.533769  178063.52
#
#             Time
# date
# 2014-04-21     0
# 2014-04-22     1
# 2014-04-23     2
# 2014-04-24     3
# 2014-04-25     4

# %%
create_data = data_prepear(df, target_col ="QG", filter_value=65)
X_train, y_train, X_test, y_test = create_data.creator()

# %%
# Normalize features 
# Define the LSTM model
model = Sequential()
model.add(LSTM(input_shape = (32,1), units= 32, return_sequences = True))
model.add(LSTM(128, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(128,return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(1, activation="linear"))
# model.add(Activation("linear"))
model.compile(loss="mse", optimizer="adam")
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32, 32)         │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32, 128)        │        82,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 305,217 (1.16 MB)
#  Trainable params: 305,217 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(
    'best_model.keras',            # Path to save the model
    monitor='val_loss',          # Metric to monitor (you can change it)
    save_best_only=True,         # Only save the best model (based on the monitored metric)
    mode='min',                  # 'min' because we want to minimize validation loss
    verbose=1                    # Verbosity mode, to see saving details in console
)
t1 = datetime.datetime.now()
history = model.fit(x=X_train, y=y_train["y_step_4 QG"], epochs=1000, batch_size=30, validation_data = (X_test, y_test["y_step_4 QG"]), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=100), checkpoint], verbose=1, shuffle=False)
# EarlyStopping(monitor='val_loss', patience=200), 
t2 = datetime.datetime.now()
print("Compilation Time : ", t2-t1)
# Out:
# Epoch 1/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.9713
# Epoch 1: val_loss improved from inf to 0.73119, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 1.8453 - val_loss: 0.7312
# Epoch 2/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9282
# Epoch 2: val_loss improved from 0.73119 to 0.72351, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8042 - val_loss: 0.7235
# Epoch 3/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9361
# Epoch 3: val_loss improved from 0.72351 to 0.71777, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8110 - val_loss: 0.7178
# Epoch 4/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9435
# Epoch 4: val_loss improved from 0.71777 to 0.71654, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8176 - val_loss: 0.7165
# Epoch 5/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.9443
# Epoch 5: val_loss improved from 0.71654 to 0.71571, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8181 - val_loss: 0.7157
# Epoch 6/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.9456
# Epoch 6: val_loss improved from 0.71571 to 0.71448, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.8192 - val_loss: 0.7145
# Epoch 7/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.9465
# Epoch 7: val_loss improved from 0.71448 to 0.71401, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.8201 - val_loss: 0.7140
# Epoch 8/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9449
# Epoch 8: val_loss improved from 0.71401 to 0.71311, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.8187 - val_loss: 0.7131
# Epoch 9/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9414
# Epoch 9: val_loss improved from 0.71311 to 0.71019, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8154 - val_loss: 0.7102
# Epoch 10/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9382
# Epoch 10: val_loss did not improve from 0.71019
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.8133 - val_loss: 0.7111
# Epoch 11/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9414
# Epoch 11: val_loss improved from 0.71019 to 0.70603, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8149 - val_loss: 0.7060
# Epoch 12/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9226
# Epoch 12: val_loss improved from 0.70603 to 0.69695, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.7983 - val_loss: 0.6970
# Epoch 13/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.8675
# Epoch 13: val_loss improved from 0.69695 to 0.61189, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.7466 - val_loss: 0.6119
# Epoch 14/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.8309
# Epoch 14: val_loss improved from 0.61189 to 0.28163, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.7066 - val_loss: 0.2816
# Epoch 15/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.0042
# Epoch 15: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.8604 - val_loss: 0.3681
# Epoch 16/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.8553
# Epoch 16: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7245 - val_loss: 0.3461
# Epoch 17/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.8301
# Epoch 17: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.6986 - val_loss: 0.3512
# Epoch 18/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.6565
# Epoch 18: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.5396 - val_loss: 0.2935
# Epoch 19/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.8138
# Epoch 19: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.6883 - val_loss: 0.3524
# Epoch 20/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.4543
# Epoch 20: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3595 - val_loss: 0.3172
# Epoch 21/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9302
# Epoch 21: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7867 - val_loss: 0.3680
# Epoch 22/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.5407
# Epoch 22: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.4347 - val_loss: 0.6478
# Epoch 23/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.4090
# Epoch 23: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3242 - val_loss: 0.4547
# Epoch 24/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.6765
# Epoch 24: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.5569 - val_loss: 0.3355
# Epoch 25/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.6164
# Epoch 25: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.5063 - val_loss: 0.4822
# Epoch 26/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4358
# Epoch 26: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3356 - val_loss: 0.3338
# Epoch 27/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4111
# Epoch 27: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3129 - val_loss: 0.4071
# Epoch 28/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3686
# Epoch 28: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2745 - val_loss: 0.4567
# Epoch 29/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3485
# Epoch 29: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2567 - val_loss: 0.4909
# Epoch 30/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3459
# Epoch 30: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2522 - val_loss: 0.4798
# Epoch 31/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3413
# Epoch 31: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2486 - val_loss: 0.4704
# Epoch 32/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3541
# Epoch 32: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2595 - val_loss: 0.4650
# Epoch 33/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2110
# Epoch 33: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1312 - val_loss: 0.4603
# Epoch 34/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.3488
# Epoch 34: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2544 - val_loss: 0.4945
# Epoch 35/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1882
# Epoch 35: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1100 - val_loss: 0.4255
# Epoch 36/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3910
# Epoch 36: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2955 - val_loss: 0.5009
# Epoch 37/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.2149
# Epoch 37: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1376 - val_loss: 0.4633
# Epoch 38/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4190
# Epoch 38: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3222 - val_loss: 0.4752
# Epoch 39/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2175
# Epoch 39: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1377 - val_loss: 0.4030
# Epoch 40/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1819
# Epoch 40: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1024 - val_loss: 0.4700
# Epoch 41/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1517
# Epoch 41: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0779 - val_loss: 0.4444
# Epoch 42/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.2041
# Epoch 42: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1228 - val_loss: 0.5363
# Epoch 43/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1478
# Epoch 43: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.0750 - val_loss: 0.4547
# Epoch 44/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3212
# Epoch 44: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2283 - val_loss: 0.4759
# Epoch 45/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1171
# Epoch 45: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0467 - val_loss: 0.4297
# Epoch 46/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1989
# Epoch 46: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1166 - val_loss: 0.4621
# Epoch 47/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0396
# Epoch 47: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.9740 - val_loss: 0.3451
# Epoch 48/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0565
# Epoch 48: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.9884 - val_loss: 0.4432
# Epoch 49/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0238
# Epoch 49: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9608 - val_loss: 0.4434
# Epoch 50/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2081
# Epoch 50: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.1258 - val_loss: 0.4102
# Epoch 51/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0548
# Epoch 51: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.9906 - val_loss: 0.4280
# Epoch 52/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1773
# Epoch 52: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0986 - val_loss: 0.3589
# Epoch 53/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9231
# Epoch 53: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8683 - val_loss: 0.3220
# Epoch 54/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7646
# Epoch 54: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.7260 - val_loss: 0.4186
# Epoch 55/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.2864
# Epoch 55: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2033 - val_loss: 0.3814
# Epoch 56/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0300
# Epoch 56: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.9709 - val_loss: 0.3922
# Epoch 57/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1720
# Epoch 57: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0983 - val_loss: 0.4633
# Epoch 58/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8596
# Epoch 58: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8109 - val_loss: 0.3378
# Epoch 59/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7319
# Epoch 59: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6934 - val_loss: 0.3928
# Epoch 60/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6696
# Epoch 60: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6362 - val_loss: 0.4137
# Epoch 61/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4326
# Epoch 61: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4241 - val_loss: 0.4469
# Epoch 62/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5833
# Epoch 62: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5636 - val_loss: 0.3238
# Epoch 63/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2839
# Epoch 63: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1906 - val_loss: 0.4278
# Epoch 64/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1408
# Epoch 64: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0605 - val_loss: 0.4670
# Epoch 65/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8941
# Epoch 65: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8385 - val_loss: 0.4440
# Epoch 66/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1233
# Epoch 66: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0461 - val_loss: 0.3696
# Epoch 67/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9621
# Epoch 67: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.9039 - val_loss: 0.4285
# Epoch 68/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9647
# Epoch 68: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.9102 - val_loss: 0.3650
# Epoch 69/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6544
# Epoch 69: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6231 - val_loss: 0.3451
# Epoch 70/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4481
# Epoch 70: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4336 - val_loss: 0.3712
# Epoch 71/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4180
# Epoch 71: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4077 - val_loss: 0.3981
# Epoch 72/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2794
# Epoch 72: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2775 - val_loss: 0.3632
# Epoch 73/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3630
# Epoch 73: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3528 - val_loss: 0.4337
# Epoch 74/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3234
# Epoch 74: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3195 - val_loss: 0.3313
# Epoch 75/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3298
# Epoch 75: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3247 - val_loss: 0.5016
# Epoch 76/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7402
# Epoch 76: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6964 - val_loss: 0.3890
# Epoch 77/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3107
# Epoch 77: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3090 - val_loss: 0.3868
# Epoch 78/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3605
# Epoch 78: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3513 - val_loss: 0.3627
# Epoch 79/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2398
# Epoch 79: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2420 - val_loss: 0.4258
# Epoch 80/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3056
# Epoch 80: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3008 - val_loss: 0.4556
# Epoch 81/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2775
# Epoch 81: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2747 - val_loss: 0.4596
# Epoch 82/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2480
# Epoch 82: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2478 - val_loss: 0.4832
# Epoch 83/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3342
# Epoch 83: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3239 - val_loss: 0.5047
# Epoch 84/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4139
# Epoch 84: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4008 - val_loss: 0.5206
# Epoch 85/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5325
# Epoch 85: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5065 - val_loss: 0.5383
# Epoch 86/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2688
# Epoch 86: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2667 - val_loss: 0.5814
# Epoch 87/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2908
# Epoch 87: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2898 - val_loss: 0.4828
# Epoch 88/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2531
# Epoch 88: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2526 - val_loss: 0.3755
# Epoch 89/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2372
# Epoch 89: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2370 - val_loss: 0.5206
# Epoch 90/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2258
# Epoch 90: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2266 - val_loss: 0.4906
# Epoch 91/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2495
# Epoch 91: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2478 - val_loss: 0.4491
# Epoch 92/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2081
# Epoch 92: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2091 - val_loss: 0.4827
# Epoch 93/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1998
# Epoch 93: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2022 - val_loss: 0.5827
# Epoch 94/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2127
# Epoch 94: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2140 - val_loss: 0.5985
# Epoch 95/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2500
# Epoch 95: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2485 - val_loss: 0.4945
# Epoch 96/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2560
# Epoch 96: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2571 - val_loss: 0.4142
# Epoch 97/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2073
# Epoch 97: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2115 - val_loss: 0.4483
# Epoch 98/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1938
# Epoch 98: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1987 - val_loss: 0.4263
# Epoch 99/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2355
# Epoch 99: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2354 - val_loss: 0.4683
# Epoch 100/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2243
# Epoch 100: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2253 - val_loss: 0.4377
# Epoch 101/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3180
# Epoch 101: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3096 - val_loss: 0.4327
# Epoch 102/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2870
# Epoch 102: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2814 - val_loss: 0.4886
# Epoch 103/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3547
# Epoch 103: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3432 - val_loss: 0.4413
# Epoch 104/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1976
# Epoch 104: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2015 - val_loss: 0.3892
# Epoch 105/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2069
# Epoch 105: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2096 - val_loss: 0.4925
# Epoch 106/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2143
# Epoch 106: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2140 - val_loss: 0.5015
# Epoch 107/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2194
# Epoch 107: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2186 - val_loss: 0.4991
# Epoch 108/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3298
# Epoch 108: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3259 - val_loss: 0.4818
# Epoch 109/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4161
# Epoch 109: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4064 - val_loss: 0.4280
# Epoch 110/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4437
# Epoch 110: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4345 - val_loss: 0.5114
# Epoch 111/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2652
# Epoch 111: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2627 - val_loss: 0.4512
# Epoch 112/1000
# 12/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2713
# Epoch 112: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2660 - val_loss: 0.4564
# Epoch 113/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2569
# Epoch 113: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2570 - val_loss: 0.4229
# Epoch 114/1000
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1854
# Epoch 114: val_loss did not improve from 0.28163
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1903 - val_loss: 0.5316
# Compilation Time :  0:00:56.548258

# %%
plt.figure(figsize=(20,6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show()

# %%
y_fit = pd.DataFrame(model.predict(X_train), index=X_train.index)
y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
ss = StandardScaler()
ss.fit(df.QG.values.reshape(df.QG.shape[0],1))
true_y_train = ss.inverse_transform(y_train["y_step_4 QG"].values.reshape(y_train["y_step_4 QG"].shape[0],1))
true_y_test = ss.inverse_transform(y_test["y_step_4 QG"].values.reshape(y_test["y_step_4 QG"].shape[0],1))
true_y_fit = ss.inverse_transform(y_fit)
true_y_pred = ss.inverse_transform(y_pred)

# %%
train_rmse = mean_squared_error(true_y_train, true_y_fit, squared=False)
test_rmse = mean_squared_error(true_y_test , true_y_pred, squared=False)
range_train =  np.max(true_y_train) - np.min(true_y_train)
range_test = np.max(true_y_test) - np.min(true_y_test)
print("train RMSE: ",train_rmse)
print("train Range:",range_train)
print("Percent_Erorr:", (train_rmse/range_train)*100, "%")
print("test_RMSE: ", test_rmse)
print("test Range:",range_test)
print("Percent_Erorr:", (test_rmse/range_test)*100, "%")
# Out:
# train RMSE:  16560.67273613492
# train Range: 221707.31
# Percent_Erorr: 7.4696106033377605 %
# test_RMSE:  24869.614567240365
# test Range: 67296.85
# Percent_Erorr: 36.95509458056412 %

# %%
plt.plot(true_y_train)
plt.plot(true_y_fit)

# %%
plt.plot(true_y_test)
plt.plot(true_y_pred)

# %%
corr = r2_score(true_y_train, true_y_fit)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_train,
    y = true_y_fit,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="Train", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'Train'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]

# %%
corr = r2_score(true_y_test, true_y_pred)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_test,
    y = true_y_pred,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="test", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'test'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]
