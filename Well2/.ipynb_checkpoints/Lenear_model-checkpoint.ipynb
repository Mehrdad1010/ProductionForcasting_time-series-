# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">This code hidden warrnings</h5>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Install librarys that we need</h5>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")
from tensorflow import keras
from sklearn.cluster import KMeans
import random
import tensorflow as tf
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from Data_Prepear import data_prepear
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.models import Sequential
import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
tf.__version__
# Out:
# '2.17.0'

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well2.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
df1 = df1[(df1["dp_tubing"] > 100) & (df1["bhp"] > 200) & (df1["bht"] > 80)]
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2013-07-24', periods=1152, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')

df = df[[
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"]]
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df.dropna(inplace=True)
df.head()
# Out:
#                    bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P  \
# date
# 2013-07-31  273.946931  105.551370  179.382345          2.540804
# 2013-08-03  277.797679  104.933215  181.302141          6.116182
# 2013-08-04  273.594368  105.439765  177.392876          9.951288
# 2013-08-05  272.298494  105.537800  176.786078          9.758748
# 2013-08-06  271.560953  105.584750  176.519376          9.882110
#
#                        QG  Time
# date
# 2013-07-31  137705.269214     7
# 2013-08-03  141268.448264    10
# 2013-08-04  161227.000000    11
# 2013-08-05  160270.490000    12
# 2013-08-06  160951.300000    13

# %%
create_data = data_prepear(df, target_col ="QG")
X, y = create_data.creator()

# %%
# Split into trai (70 a (30%)
nrow = round(0.7*X.shape[0])
X_train = X.iloc[:nrow, :]
y_train = y[:nrow]
X_test = X.iloc[nrow:,:]
y_test = y[nrow:]

# %%
# X_train = X_train.values.reshape(X_train.shape[0],X_train.shape[1],1)
# X_test = X_test.values.reshape(X_test.shape[0],X_test.shape[1],1)
# print(X_train.shape)
# print(X_test.shape)

# %% [markdown]
# <h5 style="color:rgba(0, 0, 178, 0.6);">Create a function that build a dynamic model that can change the shape of the NN model with hyper parameters(hp) parameters</h5>

# %%
y_train.columns
# Out:
# Index(['y_step_1 QG', 'y_step_2 QG', 'y_step_3 QG', 'y_step_4 QG',
#        'y_step_5 QG', 'y_step_6 QG', 'y_step_7 QG', 'y_step_8 QG',
#        'y_step_9 QG', 'y_step_10 QG'],
#       dtype='object')

# %%
model = LinearRegression() 
model.fit(X_train, y_train["y_step_1 QG"])

y_fit = pd.DataFrame(model.predict(X_train), index=X_train.index)
y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index)

# %%
train_rmse = mean_squared_error(y_train["y_step_1 QG"], y_fit, squared=False)
test_rmse = mean_squared_error(y_test["y_step_1 QG"], y_pred, squared=False)
print("train RMSE: ",train_rmse)
print("test_RMSE: ", test_rmse)
# Out:
# train RMSE:  0.35713410358562286
# test_RMSE:  0.9338551301832358

# %%
plt.plot(y_train["y_step_1 QG"])
plt.plot(y_fit)

# %%
plt.plot(y_test["y_step_1 QG"])
plt.plot(y_pred)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(
    'best_model.keras',            # Path to save the model
    monitor='val_loss',          # Metric to monitor (you can change it)
    save_best_only=True,         # Only save the best model (based on the monitored metric)
    mode='min',                  # 'min' because we want to minimize validation loss
    verbose=1                    # Verbosity mode, to see saving details in console
)
t1 = datetime.datetime.now()
history = model.fit(x=X_train, y=y_train, epochs=250, batch_size=70, validation_data = (X_test, y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=25), checkpoint], verbose=1, shuffle=False)
t2 = datetime.datetime.now()
print("Compilation Time : ", t2-t1)
# Out:
# Epoch 1/250
# 10/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4370
# Epoch 1: val_loss improved from inf to 1.59510, saving model to best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.5362 - val_loss: 1.5951
# Epoch 2/250
# 10/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3959
# Epoch 2: val_loss improved from 1.59510 to 1.47728, saving model to best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4949 - val_loss: 1.4773
# Epoch 3/250
# 10/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3796
# Epoch 3: val_loss improved from 1.47728 to 1.37198, saving model to best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4727 - val_loss: 1.3720
# Epoch 4/250
# 10/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3816
# Epoch 4: val_loss improved from 1.37198 to 1.29487, saving model to best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4731 - val_loss: 1.2949
# Epoch 5/250
# ...

# %%
plt.figure(figsize=(20,6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show()

# %%
np.shape(y_train)
# Out:
# (774,)

# %%
y_fit = pd.DataFrame(model.predict(X_train))
y_pred = pd.DataFrame(model.predict(X_test))

train_rmse = mean_squared_error(y_train, y_fit, squared=False)
test_rmse = mean_squared_error(y_test, y_pred, squared=False)
print((f"Train RMSE: {train_rmse:.2f}\n" f"Test RMSE: {test_rmse:.2f}"))

palette = dict(palette='husl', n_colors=64)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(11, 6))
ax1 = y_train.plot(ax=ax1)
ax1 = y_fit.plot(ax=ax1)
# ax1 = plot_multistep(y_train, ax=ax1, palette_kwargs=palette)
_ = ax1.legend(['FluVisits (train)', 'Forecast'])
y_tes
ax2 = y_test.plot(ax=ax2)
ax2 = y_pred.plot(ax=ax2)
_ = ax2.legend(['FluVisits (test)', 'Forecast'])
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Train RMSE: 0.53
# Test RMSE: 1.17
