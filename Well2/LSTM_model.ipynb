# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")
from tensorflow import keras
from sklearn.cluster import KMeans
import random
import tensorflow as tf
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from Data_Prepear import data_prepear
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.models import Sequential
import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib.offsetbox import AnchoredText
import seaborn as sns
tf.__version__
from xgboost import XGBRegressor
# Out:
# 2024-10-26 16:32:26.162761: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 16:32:26.165575: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 16:32:26.174584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 16:32:26.189561: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 16:32:26.193906: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 16:32:26.204847: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-26 16:32:27.018662: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well2.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
# df1 = df1[(df1["dp_tubing"] > 100) & (df1["bhp"] > 200) & (df1["bht"] > 80)]
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2014-04-21', periods=717, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')

df = df[[
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"]]
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df.dropna(inplace=True)
df.head()
# Out:
#                    bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P         QG  \
# date
# 2014-04-21  235.873938  106.375468  166.933556         11.407277  195812.61
# 2014-04-22  235.996225  106.379720  166.985180         11.345026  172837.67
# 2014-04-23  235.831538  106.386644  166.890508         11.429508  181708.34
# 2014-04-24  235.704145  106.396780  166.803572          6.683832  119219.71
# 2014-04-25  235.913569  106.402976  166.910149         11.410404  184558.56
#
#             Time
# date
# 2014-04-21     0
# 2014-04-22     1
# 2014-04-23     2
# 2014-04-24     3
# 2014-04-25     4

# %%
create_data = data_prepear(df, target_col ="QG", filter_value=90)
X_train, y_train, X_test, y_test = create_data.creator()

# %%
# Normalize features 
# Define the LSTM model
model = Sequential()
model.add(LSTM(input_shape = (32,1), units= 32, return_sequences = True))
model.add(LSTM(128, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(128,return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(1, activation="linear"))
# model.add(Activation("linear"))
model.compile(loss="mse", optimizer="adam")
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32, 32)         │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32, 128)        │        82,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 305,217 (1.16 MB)
#  Trainable params: 305,217 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(
    'best_model.keras',            # Path to save the model
    monitor='val_loss',          # Metric to monitor (you can change it)
    save_best_only=True,         # Only save the best model (based on the monitored metric)
    mode='min',                  # 'min' because we want to minimize validation loss
    verbose=1                    # Verbosity mode, to see saving details in console
)
t1 = datetime.datetime.now()
history = model.fit(x=X_train, y=y_train["y_step_4 QG"], epochs=1000, batch_size=30, validation_data = (X_test, y_test["y_step_4 QG"]), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=100), checkpoint], verbose=1, shuffle=False)
# EarlyStopping(monitor='val_loss', patience=200), 
t2 = datetime.datetime.now()
print("Compilation Time : ", t2-t1)
# Out:
# Epoch 1/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8741
# Epoch 1: val_loss improved from inf to 0.27340, saving model to best_model.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - loss: 0.8939 - val_loss: 0.2734
# Epoch 2/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8301
# Epoch 2: val_loss improved from 0.27340 to 0.27071, saving model to best_model.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.8462 - val_loss: 0.2707
# Epoch 3/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7654
# Epoch 3: val_loss did not improve from 0.27071
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.8222 - val_loss: 0.3515
# Epoch 4/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7307
# Epoch 4: val_loss improved from 0.27071 to 0.11471, saving model to best_model.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.7827 - val_loss: 0.1147
# Epoch 5/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6679
# Epoch 5: val_loss did not improve from 0.11471
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.7344 - val_loss: 1.5963
# Epoch 6/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7709
# Epoch 6: val_loss improved from 0.11471 to 0.08297, saving model to best_model.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.7815 - val_loss: 0.0830
# Epoch 7/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7242
# Epoch 7: val_loss did not improve from 0.08297
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.7518 - val_loss: 0.2252
# Epoch 8/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6345
# Epoch 8: val_loss did not improve from 0.08297
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6461 - val_loss: 0.2497
# Epoch 9/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5894
# Epoch 9: val_loss did not improve from 0.08297
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.6028 - val_loss: 1.2975
# Epoch 10/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7055
# Epoch 10: val_loss improved from 0.08297 to 0.07892, saving model to best_model.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.7138 - val_loss: 0.0789
# Epoch 11/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4745
# Epoch 11: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4815 - val_loss: 0.5976
# Epoch 12/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4790
# Epoch 12: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4834 - val_loss: 0.1153
# Epoch 13/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4432
# Epoch 13: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4514 - val_loss: 2.4811
# Epoch 14/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6060
# Epoch 14: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.6120 - val_loss: 0.2307
# Epoch 15/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6463
# Epoch 15: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6579 - val_loss: 0.8061
# Epoch 16/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5142
# Epoch 16: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5367 - val_loss: 0.1458
# Epoch 17/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4994
# Epoch 17: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5211 - val_loss: 0.1982
# Epoch 18/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4318
# Epoch 18: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4364 - val_loss: 0.1566
# Epoch 19/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3829
# Epoch 19: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.3944 - val_loss: 0.3118
# Epoch 20/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4066
# Epoch 20: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4099 - val_loss: 0.1163
# Epoch 21/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4136
# Epoch 21: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4274 - val_loss: 1.1898
# Epoch 22/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4987
# Epoch 22: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.5025 - val_loss: 0.1433
# Epoch 23/1000
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5289
# Epoch 23: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.5447 - val_loss: 0.1341
# Epoch 24/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4351
# Epoch 24: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4394 - val_loss: 0.3414
# Epoch 25/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4097
# Epoch 25: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4128 - val_loss: 0.1422
# Epoch 26/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3726
# Epoch 26: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3756 - val_loss: 0.3999
# Epoch 27/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3993
# Epoch 27: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4017 - val_loss: 0.1542
# Epoch 28/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4404
# Epoch 28: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4487 - val_loss: 0.9027
# Epoch 29/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4632
# Epoch 29: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.4650 - val_loss: 0.1376
# Epoch 30/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4114
# Epoch 30: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.4147 - val_loss: 0.2027
# Epoch 31/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3823
# Epoch 31: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3856 - val_loss: 0.1510
# Epoch 32/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4040
# Epoch 32: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.4083 - val_loss: 0.9347
# Epoch 33/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4507
# Epoch 33: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.4538 - val_loss: 0.1271
# Epoch 34/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4580
# Epoch 34: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4621 - val_loss: 0.2168
# Epoch 35/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3853
# Epoch 35: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.3879 - val_loss: 0.4249
# Epoch 36/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3542
# Epoch 36: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3563 - val_loss: 0.2018
# Epoch 37/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3379
# Epoch 37: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3401 - val_loss: 0.3011
# Epoch 38/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3156
# Epoch 38: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3170 - val_loss: 0.1972
# Epoch 39/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3355
# Epoch 39: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.3367 - val_loss: 1.0311
# Epoch 40/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3865
# Epoch 40: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3857 - val_loss: 0.1625
# Epoch 41/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3205
# Epoch 41: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3216 - val_loss: 0.7143
# Epoch 42/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3567
# Epoch 42: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3582 - val_loss: 0.1413
# Epoch 43/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3863
# Epoch 43: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3894 - val_loss: 0.2191
# Epoch 44/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4076
# Epoch 44: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4064 - val_loss: 0.3369
# Epoch 45/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3402
# Epoch 45: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3404 - val_loss: 0.2517
# Epoch 46/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3227
# Epoch 46: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3250 - val_loss: 0.1989
# Epoch 47/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3451
# Epoch 47: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3473 - val_loss: 0.9321
# Epoch 48/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4818
# Epoch 48: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4792 - val_loss: 0.1751
# Epoch 49/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3356
# Epoch 49: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3375 - val_loss: 1.0612
# Epoch 50/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3651
# Epoch 50: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3663 - val_loss: 0.1212
# Epoch 51/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4032
# Epoch 51: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.4044 - val_loss: 0.1683
# Epoch 52/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3238
# Epoch 52: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3251 - val_loss: 0.5401
# Epoch 53/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3278
# Epoch 53: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3290 - val_loss: 0.1892
# Epoch 54/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3392
# Epoch 54: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3409 - val_loss: 0.6819
# Epoch 55/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3505
# Epoch 55: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3506 - val_loss: 0.2060
# Epoch 56/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3383
# Epoch 56: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3398 - val_loss: 0.3277
# Epoch 57/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3086
# Epoch 57: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3099 - val_loss: 0.3125
# Epoch 58/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3231
# Epoch 58: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3237 - val_loss: 0.3009
# Epoch 59/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2963
# Epoch 59: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.2975 - val_loss: 0.5650
# Epoch 60/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3268
# Epoch 60: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3266 - val_loss: 0.1720
# Epoch 61/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3191
# Epoch 61: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.3214 - val_loss: 0.7942
# Epoch 62/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3930
# Epoch 62: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.3911 - val_loss: 0.1723
# Epoch 63/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3739
# Epoch 63: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3766 - val_loss: 0.9049
# Epoch 64/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4096
# Epoch 64: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.4108 - val_loss: 0.1395
# Epoch 65/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3582
# Epoch 65: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3605 - val_loss: 0.4143
# Epoch 66/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3216
# Epoch 66: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3248 - val_loss: 0.2117
# Epoch 67/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3038
# Epoch 67: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3065 - val_loss: 0.3396
# Epoch 68/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2803
# Epoch 68: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2809 - val_loss: 0.2333
# Epoch 69/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2927
# Epoch 69: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2936 - val_loss: 0.2471
# Epoch 70/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3362
# Epoch 70: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3388 - val_loss: 0.2866
# Epoch 71/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3295
# Epoch 71: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3309 - val_loss: 0.2495
# Epoch 72/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3522
# Epoch 72: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3532 - val_loss: 0.7000
# Epoch 73/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3479
# Epoch 73: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3472 - val_loss: 0.1955
# Epoch 74/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2781
# Epoch 74: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.2787 - val_loss: 0.3898
# Epoch 75/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2892
# Epoch 75: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2891 - val_loss: 0.1780
# Epoch 76/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2723
# Epoch 76: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2728 - val_loss: 0.7449
# Epoch 77/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3081
# Epoch 77: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3068 - val_loss: 0.1754
# Epoch 78/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2915
# Epoch 78: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2920 - val_loss: 0.6329
# Epoch 79/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3098
# Epoch 79: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3095 - val_loss: 0.2420
# Epoch 80/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3283
# Epoch 80: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3320 - val_loss: 0.3193
# Epoch 81/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3360
# Epoch 81: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3366 - val_loss: 0.2718
# Epoch 82/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3170
# Epoch 82: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3176 - val_loss: 0.7084
# Epoch 83/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3247
# Epoch 83: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3236 - val_loss: 0.2011
# Epoch 84/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3260
# Epoch 84: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3275 - val_loss: 0.9922
# Epoch 85/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3337
# Epoch 85: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3344 - val_loss: 0.2118
# Epoch 86/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3918
# Epoch 86: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.3963 - val_loss: 1.0418
# Epoch 87/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3662
# Epoch 87: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3660 - val_loss: 0.1949
# Epoch 88/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3527
# Epoch 88: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3534 - val_loss: 0.2437
# Epoch 89/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2838
# Epoch 89: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2850 - val_loss: 0.3432
# Epoch 90/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2715
# Epoch 90: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2723 - val_loss: 0.2695
# Epoch 91/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2693
# Epoch 91: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2696 - val_loss: 0.2703
# Epoch 92/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2641
# Epoch 92: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.2643 - val_loss: 0.2551
# Epoch 93/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2458
# Epoch 93: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2461 - val_loss: 0.2498
# Epoch 94/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2530
# Epoch 94: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2527 - val_loss: 0.3526
# Epoch 95/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2665
# Epoch 95: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2658 - val_loss: 0.1940
# Epoch 96/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2858
# Epoch 96: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2874 - val_loss: 0.5601
# Epoch 97/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3104
# Epoch 97: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3115 - val_loss: 0.2047
# Epoch 98/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3034
# Epoch 98: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3060 - val_loss: 0.3203
# Epoch 99/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2647
# Epoch 99: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2652 - val_loss: 0.2458
# Epoch 100/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2515
# Epoch 100: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2516 - val_loss: 0.5658
# Epoch 101/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2829
# Epoch 101: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2815 - val_loss: 0.7923
# Epoch 102/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4541
# Epoch 102: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4574 - val_loss: 1.2661
# Epoch 103/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4167
# Epoch 103: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4136 - val_loss: 0.2433
# Epoch 104/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3219
# Epoch 104: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3220 - val_loss: 0.3739
# Epoch 105/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3448
# Epoch 105: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3451 - val_loss: 0.1461
# Epoch 106/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3784
# Epoch 106: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3797 - val_loss: 0.3263
# Epoch 107/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3825
# Epoch 107: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3859 - val_loss: 0.2463
# Epoch 108/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3151
# Epoch 108: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.3175 - val_loss: 0.3215
# Epoch 109/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3044
# Epoch 109: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3056 - val_loss: 0.2035
# Epoch 110/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2875
# Epoch 110: val_loss did not improve from 0.07892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2887 - val_loss: 0.8840
# Compilation Time :  0:01:15.094496

# %%
plt.figure(figsize=(20,6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show()

# %%
y_fit = pd.DataFrame(model.predict(X_train), index=X_train.index)
y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
ss = StandardScaler()
ss.fit(df.QG.values.reshape(df.QG.shape[0],1))
true_y_train = ss.inverse_transform(y_train["y_step_4 QG"].values.reshape(y_train["y_step_4 QG"].shape[0],1))
true_y_test = ss.inverse_transform(y_test["y_step_4 QG"].values.reshape(y_test["y_step_4 QG"].shape[0],1))
true_y_fit = ss.inverse_transform(y_fit)
true_y_pred = ss.inverse_transform(y_pred)

# %%
train_rmse = mean_squared_error(true_y_train, true_y_fit, squared=False)
test_rmse = mean_squared_error(true_y_test , true_y_pred, squared=False)
range_train =  np.max(true_y_train) - np.min(true_y_train)
range_test = np.max(true_y_test) - np.min(true_y_test)
print("train RMSE: ",train_rmse)
print("train Range:",range_train)
print("Percent_Erorr:", (train_rmse/range_train)*100, "%")
print("test_RMSE: ", test_rmse)
print("test Range:",range_test)
print("Percent_Erorr:", (test_rmse/range_test)*100, "%")
# Out:
# train RMSE:  27733.76821698857
# train Range: 316505.2734002648
# Percent_Erorr: 8.762497989066798 %
# test_RMSE:  47543.913465729405
# test Range: 93600.22000000003
# Percent_Erorr: 50.794659954569966 %

# %%
plt.plot(true_y_train)
plt.plot(true_y_fit)

# %%
plt.plot(true_y_test)
plt.plot(true_y_pred)

# %%
corr = r2_score(true_y_train, true_y_fit)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_train,
    y = true_y_fit,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="Train", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'Train'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]

# %%
corr = r2_score(true_y_test, true_y_pred)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_test,
    y = true_y_pred,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="test", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'test'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]
