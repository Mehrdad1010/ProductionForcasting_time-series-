# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")
from tensorflow import keras
from sklearn.cluster import KMeans
import random
import tensorflow as tf
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from Data_Prepear import data_prepear
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.models import Sequential
import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib.offsetbox import AnchoredText
import seaborn as sns
tf.__version__
from xgboost import XGBRegressor
# Out:
# 2024-10-26 01:33:37.893898: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 01:33:37.896810: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-26 01:33:37.906040: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-26 01:33:37.921729: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-26 01:33:37.926155: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 01:33:37.938050: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-26 01:33:38.805674: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# read the orginal data from the csv file
df1 = pd.read_csv("well2.csv")
df1['date'] = pd.to_datetime(df1['date'], errors='coerce') #convert date column to datetime format
# df1 = df1[(df1["dp_tubing"] > 100) & (df1["bhp"] > 200) & (df1["bht"] > 80)]
# =========================================
# create a dummy date time with freq = 1D to see which days we have no data
df = pd.DataFrame({
    'date': pd.date_range(start='2014-04-21', periods=717, freq='D')
})
# =========================================
# Merge on the 'date' column, using 'left' join to keep all dates from df1
df = df.merge(df1, on='date', how='left')

df = df[[
    "date", "bhp", "bht",
    "dp_tubing", "AVG_CHOKE_SIZE_P",
    "QG"]]
df.set_index('date', inplace=True)
df['Time'] = np.arange(len(df.index))
df.dropna(inplace=True)
df.head()
# Out:
#                    bhp         bht   dp_tubing  AVG_CHOKE_SIZE_P         QG  \
# date
# 2014-04-21  235.873938  106.375468  166.933556         11.407277  195812.61
# 2014-04-22  235.996225  106.379720  166.985180         11.345026  172837.67
# 2014-04-23  235.831538  106.386644  166.890508         11.429508  181708.34
# 2014-04-24  235.704145  106.396780  166.803572          6.683832  119219.71
# 2014-04-25  235.913569  106.402976  166.910149         11.410404  184558.56
#
#             Time
# date
# 2014-04-21     0
# 2014-04-22     1
# 2014-04-23     2
# 2014-04-24     3
# 2014-04-25     4

# %%
create_data = data_prepear(df, target_col ="QG", filter_value=90)
X_train, y_train, X_test, y_test = create_data.creator()

# %%
# Normalize features 
# Define the LSTM model
model = Sequential()
model.add(LSTM(input_shape = (32,1), units= 32, return_sequences = True))
model.add(LSTM(128, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64, activation="relu",return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(128,return_sequences = True))
model.add(Dropout(0.5))
model.add(LSTM(64))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(1, activation="linear"))
# model.add(Activation("linear"))
model.compile(loss="mse", optimizer="adam")
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32, 32)         │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32, 128)        │        82,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 305,217 (1.16 MB)
#  Trainable params: 305,217 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(
    'best_model.keras',            # Path to save the model
    monitor='val_loss',          # Metric to monitor (you can change it)
    save_best_only=True,         # Only save the best model (based on the monitored metric)
    mode='min',                  # 'min' because we want to minimize validation loss
    verbose=1                    # Verbosity mode, to see saving details in console
)
t1 = datetime.datetime.now()
history = model.fit(x=X_train, y=y_train["y_step_1 QG"], epochs=1000, batch_size=30, validation_data = (X_test, y_test["y_step_1 QG"]), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=100), checkpoint], verbose=1, shuffle=False)
# EarlyStopping(monitor='val_loss', patience=200), 
t2 = datetime.datetime.now()
print("Compilation Time : ", t2-t1)
# Out:
# Epoch 1/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8454
# Epoch 1: val_loss improved from inf to 0.21765, saving model to best_model.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 0.8654 - val_loss: 0.2177
# Epoch 2/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.7818
# Epoch 2: val_loss did not improve from 0.21765
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.8004 - val_loss: 0.3764
# Epoch 3/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.7152
# Epoch 3: val_loss did not improve from 0.21765
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.7325 - val_loss: 0.3758
# Epoch 4/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.6116
# Epoch 4: val_loss did not improve from 0.21765
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6321 - val_loss: 1.6399
# Epoch 5/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6092
# Epoch 5: val_loss did not improve from 0.21765
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6235 - val_loss: 0.3996
# Epoch 6/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4905
# Epoch 6: val_loss did not improve from 0.21765
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.5213 - val_loss: 0.5800
# Epoch 7/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5049
# Epoch 7: val_loss did not improve from 0.21765
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.5234 - val_loss: 2.0930
# Epoch 8/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.6213
# Epoch 8: val_loss improved from 0.21765 to 0.06826, saving model to best_model.keras
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.6321 - val_loss: 0.0683
# Epoch 9/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4434
# Epoch 9: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4547 - val_loss: 0.7983
# Epoch 10/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4478
# Epoch 10: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4581 - val_loss: 0.1911
# Epoch 11/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3629
# Epoch 11: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3718 - val_loss: 0.6776
# Epoch 12/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4345
# Epoch 12: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4418 - val_loss: 0.1101
# Epoch 13/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4033
# Epoch 13: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4136 - val_loss: 2.2498
# Epoch 14/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4159
# Epoch 14: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4210 - val_loss: 0.0961
# Epoch 15/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3809
# Epoch 15: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3890 - val_loss: 0.9972
# Epoch 16/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4691
# Epoch 16: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4782 - val_loss: 0.1358
# Epoch 17/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4276
# Epoch 17: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4329 - val_loss: 0.5702
# Epoch 18/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3909
# Epoch 18: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3952 - val_loss: 0.6344
# Epoch 19/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3309
# Epoch 19: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3369 - val_loss: 0.1197
# Epoch 20/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3997
# Epoch 20: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.4058 - val_loss: 0.6687
# Epoch 21/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3522
# Epoch 21: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3575 - val_loss: 0.1346
# Epoch 22/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3743
# Epoch 22: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3811 - val_loss: 1.6654
# Epoch 23/1000
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3670
# Epoch 23: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.3710 - val_loss: 0.1160
# Epoch 24/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3263
# Epoch 24: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3294 - val_loss: 0.8804
# Epoch 25/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3373
# Epoch 25: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3402 - val_loss: 0.1034
# Epoch 26/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3646
# Epoch 26: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3685 - val_loss: 0.3062
# Epoch 27/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3584
# Epoch 27: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3638 - val_loss: 0.3462
# Epoch 28/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3480
# Epoch 28: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3547 - val_loss: 0.1223
# Epoch 29/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3079
# Epoch 29: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3121 - val_loss: 0.3145
# Epoch 30/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2799
# Epoch 30: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2825 - val_loss: 0.1290
# Epoch 31/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2831
# Epoch 31: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2863 - val_loss: 0.4812
# Epoch 32/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2983
# Epoch 32: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3013 - val_loss: 0.1487
# Epoch 33/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3053
# Epoch 33: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3106 - val_loss: 0.3254
# Epoch 34/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3092
# Epoch 34: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3127 - val_loss: 0.1156
# Epoch 35/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3414
# Epoch 35: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3463 - val_loss: 1.2497
# Epoch 36/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3353
# Epoch 36: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3378 - val_loss: 0.1269
# Epoch 37/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3235
# Epoch 37: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3279 - val_loss: 0.3595
# Epoch 38/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2923
# Epoch 38: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2961 - val_loss: 0.1202
# Epoch 39/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2979
# Epoch 39: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3017 - val_loss: 0.4108
# Epoch 40/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2770
# Epoch 40: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2798 - val_loss: 0.1160
# Epoch 41/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2787
# Epoch 41: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2817 - val_loss: 0.6439
# Epoch 42/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2839
# Epoch 42: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2864 - val_loss: 0.1265
# Epoch 43/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2756
# Epoch 43: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2782 - val_loss: 0.3612
# Epoch 44/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2731
# Epoch 44: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2751 - val_loss: 0.1448
# Epoch 45/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2766
# Epoch 45: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2794 - val_loss: 0.8934
# Epoch 46/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3023
# Epoch 46: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3052 - val_loss: 0.1597
# Epoch 47/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3016
# Epoch 47: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3055 - val_loss: 0.3217
# Epoch 48/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2529
# Epoch 48: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2559 - val_loss: 0.2401
# Epoch 49/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2630
# Epoch 49: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2654 - val_loss: 0.3574
# Epoch 50/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2596
# Epoch 50: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2618 - val_loss: 0.1456
# Epoch 51/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2596
# Epoch 51: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2619 - val_loss: 0.5432
# Epoch 52/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2659
# Epoch 52: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2672 - val_loss: 0.1373
# Epoch 53/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2614
# Epoch 53: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2635 - val_loss: 0.3842
# Epoch 54/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2547
# Epoch 54: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2573 - val_loss: 0.1412
# Epoch 55/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3389
# Epoch 55: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3444 - val_loss: 1.1470
# Epoch 56/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3525
# Epoch 56: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3523 - val_loss: 0.1860
# Epoch 57/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3450
# Epoch 57: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3478 - val_loss: 1.7281
# Epoch 58/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3502
# Epoch 58: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3523 - val_loss: 0.1576
# Epoch 59/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3816
# Epoch 59: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3841 - val_loss: 0.2938
# Epoch 60/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2751
# Epoch 60: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2767 - val_loss: 0.5283
# Epoch 61/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2616
# Epoch 61: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2633 - val_loss: 0.1746
# Epoch 62/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2554
# Epoch 62: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2568 - val_loss: 0.4525
# Epoch 63/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2328
# Epoch 63: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2339 - val_loss: 0.2294
# Epoch 64/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2219
# Epoch 64: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2235 - val_loss: 0.2888
# Epoch 65/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2480
# Epoch 65: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2493 - val_loss: 0.1275
# Epoch 66/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2376
# Epoch 66: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2390 - val_loss: 0.5325
# Epoch 67/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3189
# Epoch 67: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3211 - val_loss: 0.1275
# Epoch 68/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2776
# Epoch 68: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2807 - val_loss: 0.6330
# Epoch 69/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3202
# Epoch 69: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3216 - val_loss: 0.1397
# Epoch 70/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3099
# Epoch 70: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3118 - val_loss: 0.6055
# Epoch 71/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2976
# Epoch 71: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2989 - val_loss: 0.2382
# Epoch 72/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2506
# Epoch 72: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2526 - val_loss: 0.4587
# Epoch 73/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3040
# Epoch 73: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.3077 - val_loss: 0.1180
# Epoch 74/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2546
# Epoch 74: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2568 - val_loss: 0.3730
# Epoch 75/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2679
# Epoch 75: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2688 - val_loss: 0.1499
# Epoch 76/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2108
# Epoch 76: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2125 - val_loss: 0.3431
# Epoch 77/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2503
# Epoch 77: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2518 - val_loss: 0.1185
# Epoch 78/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2277
# Epoch 78: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2292 - val_loss: 0.5982
# Epoch 79/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2898
# Epoch 79: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2906 - val_loss: 0.1340
# Epoch 80/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2626
# Epoch 80: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2641 - val_loss: 0.8336
# Epoch 81/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2825
# Epoch 81: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2826 - val_loss: 0.1236
# Epoch 82/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2470
# Epoch 82: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2478 - val_loss: 0.4061
# Epoch 83/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2519
# Epoch 83: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2525 - val_loss: 0.1317
# Epoch 84/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2232
# Epoch 84: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2243 - val_loss: 0.3585
# Epoch 85/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2477
# Epoch 85: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2484 - val_loss: 0.1279
# Epoch 86/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2160
# Epoch 86: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2178 - val_loss: 0.4505
# Epoch 87/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2933
# Epoch 87: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2960 - val_loss: 0.1258
# Epoch 88/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2704
# Epoch 88: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2721 - val_loss: 1.1317
# Epoch 89/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3193
# Epoch 89: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3174 - val_loss: 0.1873
# Epoch 90/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2951
# Epoch 90: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2961 - val_loss: 0.9878
# Epoch 91/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3370
# Epoch 91: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3377 - val_loss: 0.1162
# Epoch 92/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2902
# Epoch 92: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2916 - val_loss: 0.3388
# Epoch 93/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2718
# Epoch 93: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2738 - val_loss: 0.1484
# Epoch 94/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2173
# Epoch 94: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2192 - val_loss: 0.4619
# Epoch 95/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2681
# Epoch 95: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2692 - val_loss: 0.1207
# Epoch 96/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2470
# Epoch 96: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2481 - val_loss: 0.4765
# Epoch 97/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2431
# Epoch 97: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2440 - val_loss: 0.1434
# Epoch 98/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2235
# Epoch 98: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2248 - val_loss: 0.3197
# Epoch 99/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2187
# Epoch 99: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2197 - val_loss: 0.1698
# Epoch 100/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1971
# Epoch 100: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1982 - val_loss: 0.3061
# Epoch 101/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2191
# Epoch 101: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2197 - val_loss: 0.0980
# Epoch 102/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1898
# Epoch 102: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1908 - val_loss: 0.3451
# Epoch 103/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2156
# Epoch 103: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.2157 - val_loss: 0.1148
# Epoch 104/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2097
# Epoch 104: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2100 - val_loss: 0.3517
# Epoch 105/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2263
# Epoch 105: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2264 - val_loss: 0.1074
# Epoch 106/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2019
# Epoch 106: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2020 - val_loss: 0.4026
# Epoch 107/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2054
# Epoch 107: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2055 - val_loss: 0.1154
# Epoch 108/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1981
# Epoch 108: val_loss did not improve from 0.06826
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.1982 - val_loss: 0.2951
# Compilation Time :  0:01:19.857420

# %%
plt.figure(figsize=(20,6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show()

# %%
y_fit = pd.DataFrame(model.predict(X_train), index=X_train.index)
y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
ss = StandardScaler()
ss.fit(df.QG.values.reshape(df.QG.shape[0],1))
true_y_train = ss.inverse_transform(y_train["y_step_1 QG"].values.reshape(y_train["y_step_1 QG"].shape[0],1))
true_y_test = ss.inverse_transform(y_test["y_step_1 QG"].values.reshape(y_test["y_step_1 QG"].shape[0],1))
true_y_fit = ss.inverse_transform(y_fit)
true_y_pred = ss.inverse_transform(y_pred)

# %%
train_rmse = mean_squared_error(true_y_train, true_y_fit, squared=False)
test_rmse = mean_squared_error(true_y_test , true_y_pred, squared=False)
range_train =  np.max(true_y_train) - np.min(true_y_train)
range_test = np.max(true_y_test) - np.min(true_y_test)
print("train RMSE: ",train_rmse)
print("train Range:",range_train)
print("Percent_Erorr:", (train_rmse/range_train)*100, "%")
print("test_RMSE: ", test_rmse)
print("test Range:",range_test)
print("Percent_Erorr:", (test_rmse/range_test)*100, "%")
# Out:
# train RMSE:  22533.059886612016
# train Range: 316505.2734002648
# Percent_Erorr: 7.119331581599223 %
# test_RMSE:  27470.934831677303
# test Range: 87640.96
# Percent_Erorr: 31.344858421995035 %

# %%
plt.plot(true_y_train)
plt.plot(true_y_fit)

# %%
plt.plot(true_y_test)
plt.plot(true_y_pred)

# %%
corr = r2_score(true_y_train, true_y_fit)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_train,
    y = true_y_fit,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="Train", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'Train'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]

# %%
corr = r2_score(true_y_test, true_y_pred)
fig, ax = plt.subplots()
scatter_kws = dict(
    alpha=0.75,
    s=3,
)
line_kws = dict(color="C3")
ax = sns.regplot(
    x = true_y_test,
    y = true_y_pred,
    scatter_kws= scatter_kws,
    line_kws = line_kws,
    # lowess=True,
    ax=ax,
)
at = AnchoredText(
        f"{corr:.2f}",
        prop=dict(size="large"),
        frameon=True,
        loc="upper left",
    )
at.patch.set_boxstyle("square, pad=0.0")
ax.add_artist(at)
ax.set(title="test", xlabel="True_value", ylabel="Pridct")
# Out:
# [Text(0.5, 1.0, 'test'), Text(0.5, 0, 'True_value'), Text(0, 0.5, 'Pridct')]
